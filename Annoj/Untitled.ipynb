# %%
import pandas as pd

# %%
df  = pd.read_csv('weather_data.csv')

# %%
df
# Out:
#      airport     fl_date  precip  snow  snowdepth  windgust  cloudcover  \
# 0        ATL  2018-01-01    0.00   0.0        0.0      40.7        74.3
# 1        ATL  2018-01-02    0.00   0.0        0.0       0.0        29.6
# 2        ATL  2018-01-03    0.00   0.0        0.0      29.5        67.1
# 3        ATL  2018-01-04    0.00   0.0        0.0      51.8         6.9
# 4        ATL  2018-01-05    0.00   0.0        0.0      37.1        28.0
# ...      ...         ...     ...   ...        ...       ...         ...
# 6193     SEA  2019-12-27    1.09   0.0        0.0       0.0        93.6
# 6194     SEA  2019-12-28    0.00   0.0        0.0       0.0        73.2
# 6195     SEA  2019-12-29    0.30   0.0        0.0       0.0        79.3
# 6196     SEA  2019-12-30    0.79   0.0        0.0      37.1        86.6
# 6197     SEA  2019-12-31    8.49   0.0        0.0      56.3        90.2
#
#       weather
# 0     cloudly
# 1     cloudly
# 2     cloudly
# 3        wind
# 4     cloudly
# ...

# %%
df.loc[df['weather'] == 'cloudly', 'weather'] = 'cloudy'

# %%
df = df.rename(columns ={'date': 'fl_date'})

# %%
df.windgust = df.windgust.fillna(0)

# %%
df.to_csv(r'weather_data.csv', index = False)

# %%
df
# Out:
#      airport     fl_date  precip  snow  snowdepth  windgust  cloudcover  \
# 0        ATL  2018-01-01    0.00   0.0        0.0      40.7        74.3
# 1        ATL  2018-01-02    0.00   0.0        0.0       0.0        29.6
# 2        ATL  2018-01-03    0.00   0.0        0.0      29.5        67.1
# 3        ATL  2018-01-04    0.00   0.0        0.0      51.8         6.9
# 4        ATL  2018-01-05    0.00   0.0        0.0      37.1        28.0
# ...      ...         ...     ...   ...        ...       ...         ...
# 6193     SEA  2019-12-27    1.09   0.0        0.0       0.0        93.6
# 6194     SEA  2019-12-28    0.00   0.0        0.0       0.0        73.2
# 6195     SEA  2019-12-29    0.30   0.0        0.0       0.0        79.3
# 6196     SEA  2019-12-30    0.79   0.0        0.0      37.1        86.6
# 6197     SEA  2019-12-31    8.49   0.0        0.0      56.3        90.2
#
#       weather
# 0     cloudly
# 1     cloudly
# 2     cloudly
# 3        wind
# 4     cloudly
# ...
