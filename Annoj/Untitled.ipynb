# %%
import pandas as pd

# %%
df  = pd.read_csv('weather_data.csv').drop(columns="Unnamed: 0")

# %%
df
# Out:
#      airport        date  precip  snow  snowdepth  windgust  cloudcover  \
# 0        ATL  2018-01-01    0.00   0.0        0.0      40.7        74.3
# 1        ATL  2018-01-02    0.00   0.0        0.0       NaN        29.6
# 2        ATL  2018-01-03    0.00   0.0        0.0      29.5        67.1
# 3        ATL  2018-01-04    0.00   0.0        0.0      51.8         6.9
# 4        ATL  2018-01-05    0.00   0.0        0.0      37.1        28.0
# ...      ...         ...     ...   ...        ...       ...         ...
# 6193     SEA  2019-12-27    1.09   0.0        0.0       NaN        93.6
# 6194     SEA  2019-12-28    0.00   0.0        0.0       NaN        73.2
# 6195     SEA  2019-12-29    0.30   0.0        0.0       NaN        79.3
# 6196     SEA  2019-12-30    0.79   0.0        0.0      37.1        86.6
# 6197     SEA  2019-12-31    8.49   0.0        0.0      56.3        90.2
#
#                    icon
# 0     partly-cloudy-day
# 1     partly-cloudy-day
# 2     partly-cloudy-day
# ...

# %%
df.loc[df['weather'] == 'rain', 'weather'] = 'rainy'

# %%
df = df.rename(columns ={'icon': 'weather'})

# %%
df.windgust = df.windgust.fillna(0)

# %%
df.to_csv(r'weather_data.csv', index = False)
